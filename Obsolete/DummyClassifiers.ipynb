# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split,GridSearchCV
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve, accuracy_score, \
recall_score, precision_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
import statsmodels.api as sm
from sklearn.feature_selection import RFECV
from sklearn.dummy import DummyClassifier

# %%
df4 = pd.read_csv('data/postseason15.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df5 = pd.read_csv('data/postseason16.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df6 = pd.read_csv('data/postseason17.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df7 = pd.read_csv('data/postseason18.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df8 = pd.read_csv('data/postseason19.csv').drop(['Unnamed: 0','w_loc'], axis = 1)

# %%
def create_categorical(df):
    df['w_loc_H'] = 0
    df['w_loc_N'] = 1
    return df

create_categorical(df4)
create_categorical(df5)
create_categorical(df6)
create_categorical(df7)
create_categorical(df8)
# Out:
#     W_TeamID    W_Score      W_FGM      W_FGA     W_FGM3     W_FGA3  \
# 0     1125.0  86.866667  31.666667  63.733333  10.366667  27.966667
# 1     1192.0  74.741935  26.193548  55.225806   7.806452  19.322581
# 2     1113.0  77.812500  26.593750  59.468750   7.250000  21.250000
# 3     1295.0  72.290323  24.580645  54.709677   9.709677  26.354839
# 4     1120.0  78.882353  27.029412  60.441176  11.411765  29.970588
# ..       ...        ...        ...        ...        ...        ...
# 62    1120.0  78.882353  27.029412  60.441176  11.411765  29.970588
# 63    1277.0  78.823529  27.764706  57.176471   8.294118  21.617647
# 64    1403.0  73.093750  26.156250  55.468750   7.250000  19.718750
# 65    1438.0  71.843750  25.625000  53.593750   8.468750  20.718750
# 66    1438.0  71.843750  25.625000  53.593750   8.468750  20.718750
#
#         W_FTM      W_FTA       W_OR       W_DR  ...  L_Opp_3Pr   L_Opp_TR  \
# 0   13.166667  17.900000   8.900000  29.666667  ...   0.329057  37.156250
# ...

# %%
X_test4 = df4.drop('fav_win',axis = 1)
X_test5 = df5.drop('fav_win',axis = 1)
X_test6 = df6.drop('fav_win',axis = 1)
X_test7 = df7.drop('fav_win',axis = 1)
X_test8 = df8.drop('fav_win',axis = 1)

y_test4 = df4.fav_win
y_test5 = df5.fav_win
y_test6 = df6.fav_win
y_test7 = df7.fav_win
y_test8 = df8.fav_win

# %%
print(y_test4.value_counts(normalize = True))
print(y_test5.value_counts(normalize = True))
print(y_test6.value_counts(normalize = True))
print(y_test7.value_counts(normalize = True))
print(y_test8.value_counts(normalize = True))
# Out:
# True     0.686567
# False    0.313433
# Name: fav_win, dtype: float64
# True     0.716418
# False    0.283582
# Name: fav_win, dtype: float64
# True     0.671642
# False    0.328358
# Name: fav_win, dtype: float64
# True     0.686567
# False    0.313433
# Name: fav_win, dtype: float64
# True     0.746269
# False    0.253731
# Name: fav_win, dtype: float64

# %%
tournament15 = dc.fit(X_test4)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-31-5be4836fe7cf> in <module>
# ----> 1 tournament15 = dc.predict(X_test4)
#
# ~\.conda\envs\learn-env\lib\site-packages\sklearn\dummy.py in predict(self, X)
#     209             Predicted target values for X.
#     210         """
# --> 211         check_is_fitted(self)
#     212
#     213         # numpy random_state expects Python int and not long as size argument
#
# ~\.conda\envs\learn-env\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\.conda\envs\learn-env\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
# ...

# %%
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True, False,
#         True, False,  True,  True, False, False, False,  True, False,
#         True, False, False, False,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#        False,  True, False, False,  True, False,  True,  True,  True,
#         True, False,  True,  True, False, False,  True,  True,  True,
#         True, False,  True,  True])
