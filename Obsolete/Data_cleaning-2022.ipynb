# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The files we downloaded from kaggle include in game stats for all seasons from 2003 up to 2020. Our predcitions are going to be based off the season average stats of the two relevant teams in each game. In order to get this we have to calculate the averages from all the games they played up to that point in the season, and make a new dataframe for the specific game with averages as input.

# %% [markdown]
# We then need to make a target variable. The difficulty with this dataset is, we would like to predict whether the favorite team (based on Ken Pom rankings) won the game for betting purposes, and this dataset does not include a team raking. We had to use another dataset from kaggle which includes the team rankings, check if the winning team in the game was the favorite, and then make a binary column of Favorite Win.
#
# Ken Pomeroy, the creator of KenPom, uses analytical measures to rank each team in college basketball. He is one of the most popular and well-known names in basketball analytics and has been at the forefront of the progression mainstream acceptance of advanced stats.
#
# Once we have a target column, we can create a dataframe with full seasons worth of games with a target column, and train our model on it.

# %%
import pandas as pd
import numpy as np
import time

# %%
# Importing a regular season dataframe, a postseason dataframe, a rankings dataframe, 
# and a dataframe with Ken Pom ranking from the rankings dataframe. 

regularseason = pd.read_csv('../Data/regularseason22.csv')
postseason = pd.read_csv('../MDataFiles_Stage1/MNCAATourneyDetailedResults.csv')
rankings = pd.read_csv('../MDataFiles_Stage1/MMasseyOrdinals.csv')
kenpom = pd.read_csv('../Data/KenPom20212109.csv')
team_ids = pd.read_csv('../Data/TeamNames.csv')

# %%
team_ids_dict = dict(zip(team_ids.KenPom,team_ids.TeamID))
kenpom = kenpom.rename(columns = {'RankAdjEM' : 'OrdinalRank', 'TeamName': 'TeamID'})
kenpom.TeamID = kenpom['TeamID'].replace(team_ids_dict)

# %%
regularseason.drop('Unnamed: 0', axis = 1)
# Out:
#       Season  DayNum WTeamID  WScore LTeamID  LScore  WLoc  NumOT  WFGM  WFGA  \
# 0       2022       8  1211.0      97  1469.0      63  Home      0    37    68
# 1       2022       8  1417.0      95  1167.0      58  Home      0    31    62
# 2       2022       8  1242.0      87  1277.0      74  Away      0    31    64
# 3       2022       8  1437.0      91  1291.0      51  Home      0    31    56
# 4       2022       8  1400.0      92  1223.0      48  Home      0    32    50
# ...      ...     ...     ...     ...     ...     ...   ...    ...   ...   ...
# 1664    2022      37  1395.0      76  1428.0      62  Home      0    30    67
# 1665    2022      37  1381.0      60  1430.0      56  Home      0    23    54
# 1666    2022      37  1336.0      74  1447.0      54  Home      0    24    50
# 1667    2022      37  1450.0      94  1451.0      60  Home      0    38    66
# 1668    2022      37  1459.0      78  1205.0      70  Away      0    26    53
#
#       ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0     ...     22     9    21   13   19    12   20     5     1   22
# 1     ...     17     3     8    5   26    11   13     8     2   21
# 2     ...     20     9    16    8   27    12   16     5     3   18
# 3     ...     12     6     8    7   18    16   18     2     2   15
# 4     ...     17    10    22   13   14     6   14     8     0   21
# ...   ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 1664  ...     20    21    25    6   27    14    8     4     7   14
# 1665  ...     21     9    12    7   29     5    9     6     7   13
# 1666  ...     14     4     6    7   17    14   14    10     1   20
# 1667  ...     23    15    19    3   19     6   12     5     4   13
# 1668  ...     19    12    17    7   16    11   12     9     7   24
#
# [1669 rows x 34 columns]

# %% [markdown]
# We want to have some more advanced stats to use for prediction. We create them here with a few calculations from the regular stats.

# %%
def add_rate_cols(df):
    # Calculates the number of possesions for each team in each game. The number of possessions
    # has a large effect on teams averages and counting stats. Knowing this tells us how
    # efficient a team is different factors of a game.
    df['possessions'] = .5 * (df['FGA'] + (.475 * df['FTA']) - df['OR'] + df['TO'])
    
    # Effective Field Goal Percentage (eFG) gives extra value to 3-point shots. Each 3-pointer made
    # is given the weight of 1.5 2-pointers made.
    df['eFG'] = (df['FGM'] + (.5 * df['FGM3'])) / df['FGA']
    
    # True Shooting Percentage (TS%) gives weight to the 3-point shot as well as free throws made.
    # This stat takes in account all types of scoring to determine a players shooting percentage.
    df['TS%'] = df['Score'] / (2 * (df['FGA'] + .475 * df['FTA']))
    
    # Free Throw Rate (FTr) is a simple ratio of Free Throws to Field Goals Attempted. It identifies
    # a team's abiilty to draw fouls and get to the free throw line where expected value is high.
    df['FTr'] = df['FTA'] / df['FGA']
    
    # Three Point Attempt Rate (3PAr) shows how often a player shoots 3-pointers compared to other
    # types of shots. It identifies players who attack the basket and draw fouls and players who are
    # likely to stand outside and shoot.
    df['3PAr'] = df['FGA3'] / (df['FGA'] + (.475*df['FTA']))
    
    # Offensive Rebound Percentage (OR%) is the number of offensive rebounds a team gets compared
    # to the total number of rebounds available while they were on offense.
    df['OR%'] = df['OR'] / (df['OR'] + df['Opp_DR'])
    
    # Defensive Rebound Percentage (DR%) is the number of defensive rebounds a team gets compared
    # to the total number of rebounds available while they were on defense.
    df['DR%'] = df['DR'] / (df['DR'] + df['Opp_OR'])
    
    # Rebound Percentage (REB%) is the percentage of rebounds from all available rebounds a team
    # gets in a game.
    df['REB%'] = (df['OR'] + df['DR']) / (df['OR'] + df['Opp_DR'] + df['Opp_OR'] + df['DR'])
    
    # Total Rebounds (TR) the number of rebounds a team gets in a game.
    df['TR'] = (df['OR'] + df['DR'])
    
    # Assist to Turnover Ratio (ATOr) shows how well a team takes care of the ball. The higher the
    # the number the better a team is at passing the ball and playing together.
    df['ATOr'] = df['Ast'] / df['TO']
    
    # Assist Percentage (Ast%) is the number of assists a team has compared to baskets scored. The
    # higher this percentage the better the team is at playing together and creating baskets for
    # one another.
    df['Ast%'] = df['Ast'] / df['FGM']
    
    # Steal Percentage (Stl%) is the rate at which a team gets steals during other teams possessions.
    df['Stl%'] = df['Stl'] / (df['Opp_FGA'] + .475*df['Opp_FTA'] + df['Opp_TO'])
    
    # Block Percentage (Blk%) is the rate at which a team blocks shots during other teams possessions.
    df['Blk%'] = df['Blk'] / (df['Opp_FGA'])
    
    # Turnover Percentage (TO_r) is the rate at which a team turnovers the ball over during their own
    # possessions.
    df['TO_r'] = df['TO'] / (df['FGA'] + .475*df['FTA'] + df['TO'])
    
    # Opponent Effective Field Goal Percentage (Opp_eFG) is a defensive measure that shows the Effective
    # Field Goal Percentage of a team's opponents.
    df['Opp_eFG'] = (df['Opp_FGM'] + (.5 * df['Opp_FGM3'])) / df['Opp_FGA']
    
    # Opponent True Shooting Percentage (Opp_TSpct) is a defensive measure that shows the True Shooting
    # Percentage of a team's opponents.
    df['Opp_TSpct'] = df['Opp_Score'] / (2 * (df['Opp_FGA'] + .475 * df['Opp_FTA']))
    
    # Opponent Free Throw Rate (Opp_FTr) is a defensive measure that shows how often a team fouls their
    # opponents and allows them to shoot free throws.
    df['Opp_FTr'] = df['Opp_FTA'] / df['Opp_FGA']
    
    # Opponent Three Point Rate (Opp_3Pr) is a defensive rate measure of how many 3-pointers an
    # opponent makes per basket scored.
    df['Opp_3Pr'] = df['Opp_FGA3'] / (df['Opp_FGA'] + (.475*df['Opp_FTA']))
    
    # Opponent Total Rebounds (Opp_TR) is the number of rebounds a team's opponent gets in a game.
    df['Opp_TR'] = (df['Opp_OR'] + df['Opp_DR'])
    
    # Opponent Assist to Turnover Ratio (Opp_ATOr) is a defensive rate measure of an opponents
    # assists per turnover. This is a good measure of defensive aggressiveness and the ability to make
    # opponents work hard for their shots.
    df['Opp_ATOr'] = df['Opp_Ast'] / df['Opp_TO']
    
    # Opponent Assist Percentage (Opp_Ast_%) is the percentage of opponent's baskets that are assisted.
    df['Opp_Ast_%'] = df['Opp_Ast'] / df['Opp_FGM']
    
    # Opponent Steal Percentage (Opp_Stl_%) is the percentage possesions that end with the opponent getting
    # a steal.
    df['Opp_Stl_%'] = df['Opp_Stl'] / (df['FGA'] + .475*df['FTA'] + df['TO'])
    
    # Opponent Block Percentage (Opp_Blk_%) is the percentage of opponent's possessions that end in a
    # block.
    df['Opp_Blk_%'] = df['Opp_Blk'] / (df['FGA'])
    
    # Opponent Turnover Rate (Opp_TO_r) is the percentage of opponent's possesions that end in a 
    # turnover.
    df['Opp_TO_r'] = df['Opp_TO'] / (df['Opp_FGA'] + .475*df['Opp_FTA'] + df['Opp_TO'])

    return df

# %% [markdown]
# This function will take all the in-game stats of a teams season, and put it into one dataframe. Then (if the paramter average is set to True), put that into a single row with the teams averages.

# %%
# This function is used to get the stats for a team in the regular season. The parameters are:
# the team id number, the season, the day number of the season, and whether you want to see
# each individual game or the season averages.

def team_regular_season(team_id,Season = all, DayNum = all, average = True):
    
    # create a dataframe that has all the wins/losses of a team during the season up to the given day number.
    teamwins = regularseason[(regularseason['WTeamID'] == team_id) & (regularseason['Season'] == Season) & (regularseason['DayNum'] < DayNum)] 
    teamlosses = regularseason[(regularseason['LTeamID'] == team_id) & (regularseason['Season'] == Season) & (regularseason['DayNum'] < DayNum)]
    
    # split the dataframes to only have the offensive statistics of the given team
    teamwinsoffense = teamwins.filter(like = 'W')    
    teamlossesoffense = teamlosses.filter(like = 'L')

    # split the dataframes to only have the defensive statistics of the given team
    teamwinsoffense.columns = teamwinsoffense.columns.str.lstrip('W')
    teamlossesoffense.columns = teamlossesoffense.columns.str.lstrip('L')

    # concat the two offensive dataframes
    teamoffense = pd.concat([teamwinsoffense, teamlossesoffense])

    # create oppposing team statistics from the given games
    teamwinsopponents = teamwins.filter(like = 'L')
    teamlossesopponents = teamlosses.filter(like = 'W')

    # rename the columns from the opponent statistics dataframes
    teamwinsopponents.columns = teamwinsopponents.columns.str.lstrip('L')
    teamlossesopponents.columns = teamlossesopponents.columns.str.lstrip('W')

    # concat the dataframes from opponent wins and losses
    teamopponents = pd.concat([teamwinsopponents, teamlossesopponents])
    
    # concat the team stats and the opponent stats to create a full picture of the team's season
    teamtotal = pd.concat([teamoffense, teamopponents.add_prefix('Opp_')], axis = 1)
    
    teamtotal.drop('Opp_TeamID', axis = 1, inplace = True)
    
    # return either the season averages or the game by game statistics
    if average == True:
        teamtotal = teamtotal.groupby('TeamID').mean().reset_index()
        add_rate_cols(teamtotal)
    
    if average == False:
        add_rate_cols(teamtotal)
        
    return teamtotal

# %%
# Here's an example of a team_regular_season output.
start = time.time()
marquette = team_regular_season(1266, 2022, 50, False)
end = time.time()
print('Execution time = %.6f seconds' % (end-start))
marquette
# Out:
# Execution time = 0.055820 seconds
# Empty DataFrame
# Columns: [TeamID, Score, Loc, FGM, FGA, FGM3, FGA3, FTM, FTA, OR, DR, Ast, TO, Stl, Blk, PF, WLoc, Opp_Score, Opp_WLoc, Opp_FGM, Opp_FGA, Opp_FGM3, Opp_FGA3, Opp_FTM, Opp_FTA, Opp_OR, Opp_DR, Opp_Ast, Opp_TO, Opp_Stl, Opp_Blk, Opp_PF, Opp_Loc, possessions, eFG, TS%, FTr, 3PAr, OR%, DR%, REB%, TR, ATOr, Ast%, Stl%, Blk%, TO_r, Opp_eFG, Opp_TSpct, Opp_FTr, Opp_3Pr, Opp_TR, Opp_ATOr, Opp_Ast_%, Opp_Stl_%, Opp_Blk_%, Opp_TO_r]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# Now we get the end of year rankings of a team for a specific year with this function.

# %%
def get_KenPom(team_id, Year):
    rank = kenpom[(kenpom['TeamID'] == team_id) & (kenpom['Season'] == Year)]
    rank.reset_index(inplace = True)
    return rank.OrdinalRank

get_KenPom(1181, 2022)
# Out:
# 0    7
# Name: OrdinalRank, dtype: int64

# %% [markdown]
# This function will take in a specified matchup and output a game with the two teams season stats and whether the favorite team one.

# %%
def single_game(team1_id, team2_id, Year = 2020, DayNum = 132):
    
    # from the Team IDs get a dataframe with the average seasonlong team statistics.
    team1 = team_regular_season(team1_id,Year,DayNum)
    team2 = team_regular_season(team2_id,Year,DayNum)
    
    # get the Ken Pom ranking for each team
    team1Pom = get_KenPom(team1_id, Year)
    team2Pom = get_KenPom(team2_id, Year)
    
    # due to the structure of the original dataframe, the first team listed is always the winner.
    # we check if the favorite won by comparing the rankings of the two teams.
    fav_win = pd.DataFrame(team1Pom.lt(team2Pom))
    
    # concatenate the dataframes and return the single game pre-game data.
    game = pd.concat([team1.add_prefix('W_'), team2.add_prefix('L_'), fav_win], axis = 1)
    game.rename(columns={game.columns[106]: 'fav_win'}, inplace = True)
    
    return game

# %% [markdown]
# This code shows how the stats from the function "single_game" update throughout the season. In this
# hypothetical example Duke plays North Carolina during the 2020 season on four separate occasions. On Day 0
# there are no stats available so all the values are 'Nan'. On Day 2, only Duke has played a game, they have
# stats available, however, North Carolina has not, so their values are all 'Nan'. On Day 50, both teams have
# played and have available stats. On Day 100, both teams have continued deep into their seasons and have
# updated statistics from the first 100 days of the year.

# %%
duke_unc = single_game(1181, 1314, 2022, 0)
duke_unc
# Out:
#   W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
# 0      NaN      NaN    NaN    NaN     NaN     NaN    NaN    NaN   NaN   NaN
#
#    ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
# 0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#    L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
# 0          NaN          NaN         NaN     True
#
# [1 rows x 107 columns]

# %%
duke_unc = single_game(1181, 1314, 2022, 2)
duke_unc
# Out:
#   W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
# 0      NaN      NaN    NaN    NaN     NaN     NaN    NaN    NaN   NaN   NaN
#
#    ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
# 0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#    L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
# 0          NaN          NaN         NaN     True
#
# [1 rows x 107 columns]

# %%
duke_unc = single_game(1181, 1314, 2022, 25)
duke_unc
# Out:
#   W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
# 0      NaN      NaN    NaN    NaN     NaN     NaN    NaN    NaN   NaN   NaN
#
#    ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
# 0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#    L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
# 0          NaN          NaN         NaN     True
#
# [1 rows x 107 columns]

# %%
duke_unc = single_game(1181, 1314, 2022, 30)
duke_unc
# Out:
# Empty DataFrame
# Columns: [W_TeamID, W_Score, W_FGM, W_FGA, W_FGM3, W_FGA3, W_FTM, W_FTA, W_OR, W_DR, W_Ast, W_TO, W_Stl, W_Blk, W_PF, W_Opp_Score, W_Opp_FGM, W_Opp_FGA, W_Opp_FGM3, W_Opp_FGA3, W_Opp_FTM, W_Opp_FTA, W_Opp_OR, W_Opp_DR, W_Opp_Ast, W_Opp_TO, W_Opp_Stl, W_Opp_Blk, W_Opp_PF, W_possessions, W_eFG, W_TS%, W_FTr, W_3PAr, W_OR%, W_DR%, W_REB%, W_TR, W_ATOr, W_Ast%, W_Stl%, W_Blk%, W_TO_r, W_Opp_eFG, W_Opp_TSpct, W_Opp_FTr, W_Opp_3Pr, W_Opp_TR, W_Opp_ATOr, W_Opp_Ast_%, W_Opp_Stl_%, W_Opp_Blk_%, W_Opp_TO_r, L_TeamID, L_Score, L_FGM, L_FGA, L_FGM3, L_FGA3, L_FTM, L_FTA, L_OR, L_DR, L_Ast, L_TO, L_Stl, L_Blk, L_PF, L_Opp_Score, L_Opp_FGM, L_Opp_FGA, L_Opp_FGM3, L_Opp_FGA3, L_Opp_FTM, L_Opp_FTA, L_Opp_OR, L_Opp_DR, L_Opp_Ast, L_Opp_TO, L_Opp_Stl, L_Opp_Blk, L_Opp_PF, L_possessions, L_eFG, L_TS%, L_FTr, L_3PAr, L_OR%, L_DR%, L_REB%, L_TR, L_ATOr, L_Ast%, L_Stl%, L_Blk%, L_TO_r, L_Opp_eFG, L_Opp_TSpct, L_Opp_FTr, L_Opp_3Pr, ...]
# Index: []
#
# [0 rows x 107 columns]

# %% [markdown]
# We can now write a function to create a full seasons worth of games using the single_game function to concatenate all of the single games of a season into one DataFrame.

# %%
def create_season_df(df, season):
    
    # create a DataFrame for the season we are looking for
    season_df = df[(df['Season'] == season) & (df['DayNum'] >= 12)]
    season_df.reset_index(inplace = True)
    
    # create a list with the two teams, winning team always first, the season, and the day number of the game
    matchups = list(zip(season_df.WTeamID, season_df.LTeamID, season_df.Season, season_df.DayNum))
    
    season_games = []
    
    # iterate through the list we created and create each single game matchup throughout the season
    for i in range(len(matchups)):
        game = single_game(matchups[i][0], matchups[i][1], Year = matchups[i][2], DayNum = matchups[i][3])
        season_games.append(game)
    
    # from the season games list concatenate all the outputted DataFrames and insert the location
    # of the winner (home, away, neutral)
    df = pd.concat(season_games, axis = 0).dropna()
    df.reset_index(inplace = True, drop = True)
    df.insert(0,"w_loc", season_df.WLoc)
    
    return season_games

# %% [markdown]
# Now we can simply run this last function on each season and each postseason. With that, our data cleaning is complete.

# %%
# ###7.5 seconds to run
# start_time = time.time()

regularseason22 = create_season_df(regularseason, 2022)

# end_time = time.time()
# print('Execution time = %.6f seconds' % (end_time-start_time))

# %%
regularseason22
# Out:
# [  W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1211.0       97     37     68       6      21     17     24    14    30
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.403701    0.44898   0.285955        27    0.428571        0.375
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.111966          0.0    0.190606      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1276.0       88     32     59       6      15     18     30     9    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.688992    0.40367   0.423403      32.0         1.0     0.580645
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.095801     0.121739    0.216998      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1181.0     80.5   31.0   65.5     5.0    20.5   13.5   18.0   8.0  27.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.479214   0.149123   0.450543      27.0    0.857143     0.571429
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.092075     0.034783    0.186573      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1272.0       89     35     59      13      26      6     11    10    20
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.514895   0.362069   0.397205        31    1.272727     0.583333
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.16378     0.068966    0.139285      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1116.0       74     26     55       6      21     16     22    10    23
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.405963   0.409091   0.317158        44         0.6          0.3
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.084211          0.1    0.112581      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1268.0     77.0   27.5   63.5     4.5    18.5   17.5   26.0  14.5  30.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.459492   0.358491   0.338573        34    0.352941     0.315789
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.055672          0.0    0.215122      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1163.0       99     38     62       8      13     15     19    13    20
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.604431   0.305419   0.438804  46.666667    1.583333     0.587629
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.109763     0.042683    0.134103      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1102.0       53     20     45       7      23      6     12     0    27
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.545455    0.15625   0.392727        28      1.1875     0.633333
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.094731     0.068966    0.188791      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1240.0       57     22     52       8      20      5     11     9    19
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.490756   0.069444   0.363025        41    0.857143          0.4
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.056196     0.028169    0.158416      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1283.0       94     31     60       7      26     25     35     7    23
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.53823   0.492188    0.29761      33.5    0.967742     0.526316
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.11744     0.063636    0.164086      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1247.0       81     30     79      15      40      6     14    10    27
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.517126    0.34375   0.322364        38    1.555556     0.466667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.135777     0.075472    0.107849      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1339.0     91.0   31.5   61.5     8.5    22.0   19.5   26.0   6.5  32.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.55666   0.405172   0.455449      34.0    1.178571       0.6875
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.062893     0.044248    0.168345      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1258.0       64     22     57       7      28     13     21    15    19
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1223.0       48     16     49       6      17     10     22    13    14
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1293.0      109     38     60      13      26     20     30     9    32
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.687925   0.517857   0.515944        40        1.75         0.75
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.096154     0.050847    0.146744      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1414.0       51     19     62       4      21      9     12    11    22
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.507017       0.22   0.199185        26    0.176471     0.130435
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.052511     0.016129    0.235376      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1271.0     58.0   22.0   63.5     9.0    26.0    5.0    8.0   9.0  22.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0      NaN      NaN    NaN    NaN     NaN     NaN    NaN    NaN   NaN   NaN
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.634129   0.203125   0.285002        37         1.5     0.416667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.106277     0.103448    0.124727      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1424.0       64     20     66       2      25     22     27    16    28
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.674536   0.608696   0.370995        30    0.833333     0.416667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.062189     0.033333    0.168303      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1311.0     91.0   39.0   62.5     8.0    21.5    5.0   11.5   6.5  29.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.745548   0.075862   0.346147      35.0    2.076923     0.556701
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.225829     0.036036    0.147539      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1416.0       69     28     64       6      24      7     10    10    22
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.482709   0.413793   0.302594        25    1.076923     0.583333
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.119832         0.05    0.157767      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1177.0       97     36     76       9      30     16     20    18    30
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.545836   0.360656   0.377887        39         1.4     0.518519
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.07533     0.065574    0.122775      NaN
#
#  [1 rows x 107 columns],
#               W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  \
#  0  Northwestern State     67.0   27.5   60.5     6.5    22.0    5.5   11.5
#
#     W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  \
#  0   8.0  22.5  ...     0.623475   0.126437   0.206018        48         2.5
#
#     L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.612245     0.241427     0.018868    0.115136      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1301.0       88     33     72       7      24     15     20    16    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.483535       0.42   0.233431        37    0.714286          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.041899     0.017857    0.189253      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1171.0       57     21     56       6      29      9     13     8    22
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1362.0     95.0   33.0   58.0    11.5    27.0   17.5   23.5  11.5  24.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.519006   0.421053   0.321637        30    0.692308     0.391304
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.081633     0.018519    0.159705      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1174.0       71     23     57       6      22     19     24    13    17
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.551673   0.362069   0.205958        34    1.666667     0.344828
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.101818         0.16    0.081108      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1405.0       69     24     55       6      15     15     18     8    27
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.641267   0.145161   0.347039        37    2.666667     0.470588
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.041479     0.051724    0.083016      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1184.0     98.0   37.5   71.0    14.0    36.5    9.0   16.5  12.0  22.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.396563   0.202899   0.383344        40         1.0          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.039867     0.018868    0.116754      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1125.0       80     28     60       9      26     15     16     4    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.45327   0.262136   0.319447      30.0       0.875     0.512195
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.067139     0.086957    0.171643      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1260.0      103     38     72      20      46      7     11     9    42
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.418349   0.245902   0.366972        23    0.533333     0.363636
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.067077     0.030769    0.180451      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1471.0       80     24     46      10      22     22     28     1    29
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.462933      0.496   0.187763      42.5    0.678571     0.404255
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.092942       0.0625    0.153467      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1153.0       65     25     55       7      23      8     17     6    33
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.418719   0.067797    0.44335        33        0.75          0.6
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.10979     0.105263    0.208062      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1204.0       82     30     57       7      21     15     23     8    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.43654   0.101695   0.371867        30         1.2     0.545455
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.069517     0.074074    0.139179      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1119.0     69.5   28.5   60.5     5.5    22.0    7.0   12.5   6.0  30.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.559629    0.14876   0.270166      31.5    1.388889     0.416667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.115863     0.089109    0.121993      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1233.0       65     24     49       3      15     14     20     6    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.564289   0.358491   0.274083        28    0.521739         0.48
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.056417     0.031746    0.270509      NaN
#
#  [1 rows x 107 columns],
#                  W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  \
#  0  Hawaii-Hilo\r\n\t\t\t     70.5   26.0   63.5     8.5    24.0   10.0   13.5
#
#     W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  \
#  0   4.5  21.0  ...     0.504676   0.261905   0.232927      35.5    0.482759
#
#     L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.264151     0.079143     0.026786    0.169914      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1220.0       75     29     74      12      43      5      5    13    25
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.497756   0.157895   0.261118        32        0.75     0.346154
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.054663      0.04918    0.163767      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1224.0    102.5   36.5   71.0    10.5    26.5   19.0   27.0  12.5  30.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.507678   0.439394   0.250705        47    0.857143     0.545455
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.099861     0.044118    0.149294      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1227.0       54     21     57      10      28      2      2     5    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.54288   0.327273   0.236035        35    1.181818     0.541667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.041479     0.033333    0.147552      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1275.0       72     25     64       6      31     16     21     7    23
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.393082   0.285714   0.345912        25    1.571429     0.611111
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.029049          0.0     0.09915      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1167.0       58     24     64       7      17      3      8     5    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1252.0     91.0   29.0   64.5     9.0    24.0   24.0   31.0   7.5  28.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.506712   0.342723   0.339154  44.333333       1.175     0.534091
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.101394     0.064171    0.139046      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1158.0     96.0   33.5   79.5    10.0    30.0   19.0   26.5  14.5  34.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.548758    0.40708   0.259548      33.5    0.931034     0.509434
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.106217     0.078947    0.176991      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1426.0       45     20     53       2      20      3     10     7    20
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.545194     0.1875   0.315638        37    0.809524     0.548387
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.162554     0.148148    0.231533      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1262.0       91     35     70       7      20     14     21    10    33
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.465919   0.035088   0.483175        26       1.875     0.714286
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.070497     0.039216    0.121304      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1457.0      110     39     66      13      26     19     25     8    32
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.565317        0.4   0.320856        33    0.866667          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.169372     0.039216    0.186451      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1353.0       73     27     72       1      13     18     25    13    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.402129   0.236842    0.30751      40.5    0.409091     0.486486
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.112583     0.085714    0.257574      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1404.0       62     26     58       7      23      3      9     8    24
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1465.0       87     29     69      11      31     18     26    17    37
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.798658   0.307692    0.33557        47         1.5     0.666667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.092807     0.130435     0.21164      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1284.0       66     24     55       4      19     14     15     8    29
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.469405   0.264151   0.402347        27    0.571429     0.421053
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.03595     0.078125    0.190088      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1280.0       75     27     56       6      18     15     26    13    29
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.245678   0.037037   0.363967        29    0.333333     0.416667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.067981     0.052632    0.214439      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1386.0       69     26     66      10      31      7     16    11    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.586881   0.220339   0.421941      20.5    2.357143     0.589286
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.101378     0.016667    0.096986      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1123.0       71     25     57      11      30     10     21    10    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.418349   0.245902    0.26422        32    0.357143     0.238095
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.051965          0.0    0.170472      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1160.0       94     29     57       9      19     27     37    11    24
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.605861   0.353846   0.342443        38    0.941176          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.046017          0.0    0.182943      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1312.0       54     18     53       6      21     12     19    12    25
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.435171   0.347222   0.154993        39    1.272727     0.518519
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.160781     0.105263    0.115942      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1466.0       49     19     61       8      32      3      4    10    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1239.0       79     28     60       6      20     17     21    12    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.444791   0.303571   0.312134        46      0.8125     0.619048
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.040296     0.016949    0.199813      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1325.0       92     33     68      16      37     10     12     8    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.576682   0.574468   0.317593        35    0.923077     0.571429
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.013624        0.125     0.17851      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1241.0      135     55     86      17      40      8     16    12    39
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.45854   0.046875    0.48911        30       1.625     0.541667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.042179     0.016667    0.108955      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1218.0     87.5   29.0   63.5     8.5    25.5   21.0   25.5  12.0  32.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.538271   0.173554   0.343577      28.0    0.777778        0.375
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.066737      0.02439    0.170913      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1103.0       66     25     58       7      22      9     12    10    19
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1214.0      101     42     72      11      24      6      8    14    32
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.689772   0.259542   0.407747      39.0    2.947368     0.736842
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.159363     0.067308    0.114354      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1428.0       70     24     62       7      23     15     23    19    33
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.420677   0.238095   0.256684        28    0.785714          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.089762     0.101449    0.166419      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1385.0      119     45     65      13      25     16     20    10    37
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.510524   0.627907   0.250784        30    0.631579     0.666667
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.119546     0.206897    0.253926      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1455.0       60     22     57       4      22     12     14    12    23
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.292544   0.274194   0.214056        35         0.1        0.125
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.019846     0.025641    0.222037      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1380.0       60     21     68       8      24     10     17    12    22
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.489408    0.37931   0.467495        32    1.166667          0.7
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.050826     0.064516    0.149161      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1425.0       89     36     64       6      20     11     13    11    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.378378   0.166667   0.478764        27    0.833333     0.588235
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.103093     0.035088    0.156352      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1309.0       61     24     54       5      15      8     10     4    25
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.555473   0.351724   0.354558      46.5    0.848485     0.424242
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.162118     0.104348    0.163185      NaN
#
#  [1 rows x 107 columns],
#            W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  \
#  0  St. Thomas (MN)       72     26     60      13      32      7      9     4
#
#     W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  \
#  0    22  ...      0.54326   0.272727   0.295104        43    1.090909
#
#     L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.413793     0.078023     0.063492     0.12858      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1313.0     95.0   38.5   63.5     6.5    18.0   11.5   17.5   9.5  33.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.506329   0.295775   0.209941        37         2.0     0.516129
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.067893     0.013889    0.089913      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1308.0       62     20     53       7      23     15     16     6    30
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.431982      0.375    0.33346        34    0.307692     0.421053
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.067397          0.0    0.282686      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1139.0     70.5   21.0   45.5     8.5    23.5   20.0   26.5   7.0  26.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.347826   0.086207   0.347826        26    0.258065          0.5
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.101294          0.0    0.339261      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1447.0       77     32     58       7      18      6      9     8    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.417633   0.241379   0.324826        35    0.578947     0.611111
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.14701     0.046512    0.227137      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1194.0       92     32     65       8      26     20     23    14    24
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1464.0       59     22     56      10      24      5     10     6    18
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.613377   0.583333   0.339315        30    1.857143     0.419355
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.072159     0.017857    0.083707      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1397.0       90     33     77      17      40      7     13    22    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.569777   0.346154   0.412882        34        1.25     0.652174
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.056457          0.0    0.165403      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1196.0       74     25     59       8      25     16     29    16    21
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.522193   0.327586   0.402835        25    0.423077     0.478261
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.039158     0.026667    0.279495      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1382.0       75     29     58       4      14     13     21    10    24
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.567779   0.366667   0.276792      38.5     1.21875     0.684211
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.11782     0.083333    0.185078      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1114.0     92.0   38.0   73.0     5.0    17.0   11.0   14.5  10.5  24.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1461.0       85     34     62       9      23      8      9     7    30
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.657345   0.270492   0.297803      42.0    1.181818     0.557143
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.069015     0.120567     0.19335      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1127.0       69     28     71       6      35      7     15    16    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.561506   0.279412   0.428432      35.5         1.7     0.548387
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.087007     0.046512     0.11491      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1189.0     84.0   29.0   58.0    12.5    26.5   13.5   19.5   7.0  26.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1135.0     88.0   36.5   74.0     8.5    27.0    6.5    8.5  13.5  20.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.696938   0.306452   0.183034        33    1.142857     0.421053
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.185874     0.176471    0.164657      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1351.0     71.0   24.5   56.0     6.5    21.0   15.5   20.0  10.5  26.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.470253   0.203125   0.491628      37.0    0.914286     0.680851
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.037299     0.027397    0.199601      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1393.0       97     37     68      13      26     10     13     8    33
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.516399   0.215385   0.279135        32        1.25     0.357143
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          0.0     0.013889    0.100439      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1320.0     57.5   17.0   51.5     4.5    22.0   19.0   28.5   6.5  24.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1130.0     79.0   29.5   54.0     5.0    16.0   15.0   22.5   6.5  24.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.587372   0.705882   0.264317        28    1.142857     0.615385
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.081277     0.111111    0.170524      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1232.0     74.0   27.0   60.0     5.5    20.5   14.5   18.0   7.5  22.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1370.0     65.0   21.0   56.5     8.5    25.5   14.5   18.5   8.5  20.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.506329   0.413462   0.281294      32.0    0.733333     0.488889
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.085771     0.046296    0.194269      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1415.0     59.5   21.5   56.0    10.0    25.5    6.5    9.5   7.0  24.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score  W_FGM  W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1252.0  91.666667   30.0   61.0  8.333333  21.333333  23.333333
#
#         W_FTA  W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  28.666667   7.0  28.333333  ...     0.536326   0.426136   0.297696
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  36.333333    0.931818     0.525641      0.09833     0.061453    0.172127
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1255.0     76.5   28.5   74.0     9.0    34.0   10.5   16.0  16.0  23.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.666227   0.111111   0.316623        46    2.384615     0.738095
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.174672     0.092308    0.146396      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1278.0     72.0   24.0   55.5    10.0    26.5   14.0   19.0   4.5  25.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.375391   0.231481   0.367049      30.5    0.394737     0.428571
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.100204     0.051282    0.240697      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1206.0     80.5   31.5   58.0     9.5    25.5    8.0   12.5   5.5  30.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.43956    0.38843   0.258155      32.0    0.276316     0.488372
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.055479     0.039216    0.346518      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1151.0       75     25     56       6      17     19     25     9    24
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.515992   0.336066   0.240325      29.0    0.851852     0.418182
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.119976     0.042373    0.160261      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1399.0       65     24     62       6      22     11     14     7    15
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1368.0     97.5   34.5   71.0    14.5    36.0   14.0   19.0  12.0  31.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1335.0     68.0   23.5   60.0    10.0    27.0   11.0   14.0   6.5  19.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.539877   0.277778   0.294479        42         1.0     0.212121
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.15873     0.031746    0.079096      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1161.0    100.0   37.5   65.0     9.5    20.0   15.5   17.5   7.5  34.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1244.0     58.5   18.5   55.5     5.0    19.5   16.5   23.0   9.5  22.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1329.0     71.5   28.0   62.0     6.0    21.0    9.5   14.5  13.5  26.5
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...      0.63968   0.463415    0.41979      38.0    0.890909     0.563218
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.087056     0.095506    0.215602      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1412.0     93.5   36.5   66.0     8.0    20.5   12.5   18.5   8.0  19.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1286.0       90     33     69      12      30     12     14    11    15
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...          NaN        NaN        NaN       NaN         NaN          NaN
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1179.0       87     29     55      12      23     17     22     7    26
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.522682   0.266667   0.453649        27         0.5          0.4
#
# ...
#         W_FTA       W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  17.333333  10.166667  24.0  ...     0.589458   0.288416   0.343071
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  35.142857     1.20202     0.563981     0.097054     0.066059    0.170704
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1163.0  87.571429  30.142857  65.714286  8.142857  21.428571  19.142857
#
#         W_FTA  W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  24.857143  14.0  27.714286  ...     0.502576   0.292754    0.36898
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  32.833333    0.952941     0.570423     0.086576         0.05    0.177834
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM  W_FGA  W_FGM3  W_FGA3      W_FTM  W_FTA  \
#  0   1452.0     73.0  27.333333   60.0     6.0    20.0  12.333333   19.0
#
#          W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  \
#  0  10.333333  19.166667  ...     0.563411   0.299505    0.41389      31.0
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.280488     0.570652     0.100206      0.04244    0.150881      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1469.0  70.833333  24.666667  59.166667  6.333333  19.666667  15.166667
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  21.833333  6.666667  21.666667  ...     0.567433   0.403846   0.371117
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      66.0    1.153846     0.633803     0.080961     0.045161    0.173391
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM      W_FGA  W_FGM3     W_FGA3      W_FTM  \
#  0   1151.0     73.5  27.666667  59.833333     7.5  21.333333  10.666667
#
#     W_FTA  W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  \
#  0   14.5  11.0  25.166667  ...     0.565893   0.188889   0.341575  28.166667
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.213483     0.624277     0.090121     0.084399    0.184916      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA     W_FGM3  W_FGA3  W_FTM  \
#  0   1440.0  78.857143  28.285714  62.571429  13.285714    35.0    9.0
#
#         W_FTA      W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  11.571429  9.428571  28.0  ...          NaN        NaN        NaN
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0       NaN         NaN          NaN          NaN          NaN         NaN
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA  W_FGM3     W_FGA3      W_FTM  \
#  0   1353.0  66.666667  24.666667  61.166667     4.5  18.666667  12.833333
#
#         W_FTA  W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  18.666667  11.5  25.833333  ...     0.481283   0.216216   0.365419
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  29.142857    0.840909     0.480519     0.072111     0.050132    0.163934
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3  W_FTM  \
#  0   1172.0     75.5  27.666667  57.166667  9.166667  21.666667   11.0
#
#         W_FTA  W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  \
#  0  14.833333   5.5  23.0  ...     0.576585   0.282609   0.322632      31.4
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.096154     0.428571     0.056007     0.043478    0.142446      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3  W_FGA3      W_FTM  \
#  0   1318.0  59.857143  21.428571  50.142857  5.857143    20.0  11.142857
#
#         W_FTA  W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  \
#  0  15.714286   6.0  25.0  ...     0.638347   0.315603   0.329967      31.8
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.528302     0.525974     0.098477     0.034843    0.140481      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM   W_FTA  W_OR  W_DR  \
#  0   1422.0   67.125  24.25   57.0   6.375  19.375  12.25  17.625  11.5  29.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.555268   0.446115   0.297798      35.0    1.073171     0.497175
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.090167     0.060386    0.144992      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1264.0     70.8   26.0   54.2     5.6    16.4   13.2   19.0   8.6  22.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.585317   0.438356    0.31746      37.8    1.526316     0.625899
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.086779     0.084507    0.139092      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA     W_FGM3  W_FGA3      W_FTM  \
#  0   1202.0  86.833333  31.833333  64.833333  12.833333    30.0  10.333333
#
#     W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0   13.5  7.833333  25.833333  ...     0.489108   0.336927   0.316003
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  34.666667    1.076923     0.552632     0.071984     0.058201     0.15343
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score  W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1365.0  79.428571   29.0  56.857143  8.285714  19.714286  13.142857
#
#         W_FTA  W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  16.857143   6.0  24.285714  ...     0.541595   0.305842   0.369065
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      26.4    0.981132     0.403101     0.085091     0.055749    0.137208
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score  W_FGM      W_FGA  W_FGM3     W_FGA3      W_FTM  \
#  0   1291.0  65.142857   23.0  54.142857     5.0  16.285714  14.142857
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  19.714286  8.428571  20.857143  ...     0.532831   0.351759   0.307858
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  30.571429    0.765625     0.566474     0.090135     0.057471    0.216034
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM  W_FGA  W_FGM3  W_FGA3      W_FTM  W_FTA  \
#  0   1393.0  78.666667  27.666667   59.5     8.0    21.0  15.333333   19.5
#
#         W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  \
#  0  8.166667  24.0  ...     0.412012   0.302198   0.278679  31.166667
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.62963     0.435897     0.092721     0.056213    0.162896      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA  W_FGM3  W_FGA3      W_FTM  \
#  0   1266.0  74.857143  24.571429  56.714286     8.0    25.0  17.714286
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  24.857143  7.285714  25.857143  ...     0.546544   0.390533   0.277015
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  34.833333    1.097561      0.56962     0.089696     0.096317    0.169878
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3     W_FTM  \
#  0   1347.0     61.0  22.285714  54.714286  6.571429  21.142857  9.857143
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  14.142857  7.857143  23.285714  ...     0.533587   0.313869   0.406543
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      48.5    1.275862     0.606557     0.106134     0.097561    0.155559
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM  W_FGA  W_FGM3     W_FGA3     W_FTM  W_FTA  \
#  0   1144.0     67.0  26.166667   56.0     6.0  17.833333  8.666667   13.0
#
#         W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  \
#  0  7.333333  23.833333  ...          NaN        NaN        NaN       NaN
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0         NaN          NaN          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM      W_FGA  W_FGM3  W_FGA3      W_FTM  W_FTA  \
#  0   1361.0     62.5  21.666667  53.833333     4.5    17.0  14.666667   23.0
#
#         W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  \
#  0  6.833333  24.333333  ...     0.591206   0.297927   0.338156  29.833333
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.351351     0.537634     0.087934     0.078261    0.143794      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1174.0  77.428571  26.142857  53.285714  7.285714  20.857143  17.857143
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  22.285714  7.857143  20.571429  ...     0.547092    0.42671   0.362922
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      38.2    0.813333     0.451852     0.109839     0.073579    0.168833
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1207.0     70.4   25.2   58.0     8.4    22.0   11.6   17.8   9.8  26.0
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...        0.484   0.206549   0.431242  26.714286    0.988636     0.564935
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0      0.05431     0.063877    0.167955      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1278.0     72.8   26.6   57.0     7.2    20.8   12.4   18.2   3.4  29.4
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.537198   0.276968   0.422544  27.833333    1.571429     0.598639
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.113191     0.066667    0.126091      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score  W_FGM  W_FGA     W_FGM3     W_FGA3      W_FTM  \
#  0   1359.0  79.666667   27.0   62.0  10.333333  30.333333  15.333333
#
#         W_FTA  W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  \
#  0  19.166667   9.5  24.0  ...          NaN        NaN        NaN       NaN
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0         NaN          NaN          NaN          NaN         NaN      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3  W_FGA3      W_FTM  \
#  0   1307.0  80.142857  28.142857  60.428571  8.571429    22.0  15.285714
#
#         W_FTA      W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  20.571429  6.571429  21.0  ...     0.510907   0.239437    0.36674
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  26.666667    1.258621     0.496599     0.078835     0.029586    0.127929
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM  W_FGA  W_FGM3     W_FGA3      W_FTM  \
#  0   1401.0  70.285714  24.428571   56.0     7.0  18.857143  14.428571
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  21.714286  9.571429  22.428571  ...     0.520265   0.248815   0.377219
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  30.857143    1.087379     0.618785     0.092496     0.062053    0.179169
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score  W_FGM  W_FGA  W_FGM3     W_FGA3     W_FTM      W_FTA  \
#  0   1166.0  73.285714   29.0   58.0     6.0  19.714286  9.285714  14.714286
#
#         W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  \
#  0  8.285714  28.857143  ...     0.489837    0.21727   0.282793  33.166667
#
#     L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0    1.245902     0.517007     0.068814     0.057471    0.133465      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1448.0  82.714286  29.142857  59.285714  8.714286  24.285714  15.714286
#
#         W_FTA      W_OR  W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  22.142857  8.714286  25.0  ...      0.48829   0.328221    0.33968
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      28.5    0.835165     0.603175     0.046863      0.06469    0.194517
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM  W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1187.0     76.0  26.714286   59.0  7.857143  21.285714  14.714286
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  20.285714  8.428571  24.857143  ...     0.544784   0.286486   0.397288
#
#      L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0  30.571429    1.164706     0.603659      0.07523      0.03886      0.1682
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID    W_Score      W_FGM      W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1305.0  78.142857  28.571429  62.857143  7.857143  22.428571  13.142857
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  16.571429  7.714286  24.857143  ...     0.545583   0.339168   0.295878
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0     32.75    1.027273     0.535545     0.104974     0.029148    0.171707
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score  W_FGM  W_FGA  W_FGM3  W_FGA3  W_FTM  W_FTA  W_OR  W_DR  \
#  0   1245.0     69.0   24.8   54.6     7.8    22.6   11.6   14.0   7.8  22.2
#
#     ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  \
#  0  ...     0.594841    0.35461   0.412747      52.5         1.6     0.571429
#
#     L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.111095     0.142857    0.131752      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score   W_FGM  W_FGA  W_FGM3  W_FGA3   W_FTM  W_FTA   W_OR  \
#  0   1355.0     87.5  31.625  61.75  10.875   24.75  13.375  19.25  7.875
#
#      W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr   L_Opp_TR  L_Opp_ATOr  \
#  0  26.75  ...     0.609877   0.528646    0.34969  35.714286    0.859504
#
#     L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  fav_win
#  0     0.547368     0.110289     0.066496    0.201189      NaN
#
#  [1 rows x 107 columns],
#    W_TeamID  W_Score      W_FGM  W_FGA    W_FGM3     W_FGA3      W_FTM  \
#  0   1315.0     66.0  23.142857   59.0  7.857143  25.285714  11.857143
#
#         W_FTA      W_OR       W_DR  ...  L_Opp_TSpct  L_Opp_FTr  L_Opp_3Pr  \
#  0  16.571429  7.571429  21.428571  ...     0.692308   0.322581   0.370629
#
#     L_Opp_TR  L_Opp_ATOr  L_Opp_Ast_%  L_Opp_Stl_%  L_Opp_Blk_%  L_Opp_TO_r  \
#  0      37.0    2.823529     0.657534     0.097527      0.07619     0.10625
#
#     fav_win
#  0      NaN
#
#  [1 rows x 107 columns],
#  ...]

# %%
# postseason13 = create_season_df(postseason, 2013)
# postseason14 = create_season_df(postseason, 2014)
# postseason15 = create_season_df(postseason, 2015)
# postseason16 = create_season_df(postseason, 2016)
# postseason17 = create_season_df(postseason, 2017)
# postseason18 = create_season_df(postseason, 2018)
# postseason19 = create_season_df(postseason, 2019)

# %%
# start_time = time.time()

# regularseason12 = create_season_df(regularseason, 2012)

# end_time = time.time()
# print('Execution time = %.6f seconds' % (end_time-start_time))

# %%
# regularseason13 = create_season_df(regularseason, 2013)

# %%
# regularseason14 = create_season_df(regularseason, 2014)

# %%
# regularseason15 = create_season_df(regularseason, 2015)

# %%
# regularseason16 = create_season_df(regularseason, 2016)

# %%
# regularseason17 = create_season_df(regularseason, 2017)

# %%
# regularseason18 = create_season_df(regularseason, 2018)

# %%
# regularseason19 = create_season_df(regularseason, 2019)

# %%
# regularseason20 = create_season_df(regularseason, 2020)

# %% [markdown]
# Because this is so computationally expensive we can save these data frames as csv files so we never need to create these dataframes again. So We'll comment out those lines of code.

# %%
# postseason12.to_csv('./data/postseason12.csv')
# postseason13.to_csv('./data/postseason13.csv')
# postseason14.to_csv('./data/postseason14.csv')
# postseason15.to_csv('./data/postseason15.csv')
# postseason16.to_csv('./data/postseason16.csv')
# postseason17.to_csv('./data/postseason17.csv')
# postseason18.to_csv('./data/postseason18.csv')
# postseason19.to_csv('./data/postseason19.csv')

# %%
# regularseason12.to_csv('./data/regularseason12.csv')
# regularseason13.to_csv('./data/regularseason13.csv')
# regularseason14.to_csv('./data/regularseason14.csv')
# regularseason15.to_csv('./data/regularseason15.csv')
