# %%
# Import the relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split,GridSearchCV
from sklearn.metrics import plot_confusion_matrix, plot_roc_curve, accuracy_score, \
recall_score, precision_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
import statsmodels.api as sm
from sklearn.feature_selection import RFECV

import warnings
warnings.filterwarnings("ignore")

# %%
#Import functions notebook and load data set here
import sys
sys.path.append("../")
from function_notebook_1 import *

# %%
#training data 2012 - 2018
df1 = pd.read_csv('../data/postseason09.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df2 = pd.read_csv('../data/postseason10.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df3 = pd.read_csv('../data/postseason11.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df4 = pd.read_csv('../data/postseason12.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df5 = pd.read_csv('../data/postseason13.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df6 = pd.read_csv('../data/postseason14.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
df7 = pd.read_csv('../data/postseason15.csv').drop(['Unnamed: 0','w_loc'], axis = 1)

df = pd.concat([df1, df2, df3, df4, df5, df6, df7])
df['w_loc_H'] = 0
df['w_loc_N'] = 1

#testing data 2019
dftest = pd.read_csv('../data/postseason16.csv').drop(['Unnamed: 0','w_loc'], axis = 1)
dftest['w_loc_H'] = 0
dftest['w_loc_N'] = 1

# %%
#train_test_split
X_train=df.drop('fav_win',axis=1)
X_test=dftest.drop('fav_win',axis=1)
y_train=df['fav_win']
y_test = dftest['fav_win']

X_train.shape, X_test.shape
# Out:
# ((463, 108), (67, 108))

# %%
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# ### Logistic Regression

# %%
log_feat=feature_select(X_train_scaled,y_train,LogisticRegression,min_features=10)
X_train_best_log = X_train_scaled[log_feat]
X_test_best_log = X_test_scaled[log_feat]

# %%
logreg(X_train_best_log, X_test_best_log, y_train, y_test)
# Out:
# Penalty: l1
# Solver: liblinear
# Mean Cross-Val Score: 0.8315334268349697
# Train Mean Accuracy: 0.8596112311015118
# Test Mean Accuracy: 0.7164179104477612
# Recall Score: 0.8333333333333334
# Precision Score: 0.7843137254901961
# F1 Score: 0.8080808080808081

# %% [markdown]
# ### KNN

# %%
#knn(X_train_scaled, X_test_scaled, y_train, y_test)

# %% [markdown]
# ### Decision Tree

# %%
#dtree_feats=feature_select(X_train_scaled,y_train,DecisionTreeClassifier,min_features=10)

# %%
#X_train_best_dtree=X_train[dtree_feats]
#X_test_best_dtree=X_test[dtree_feats]

# %%
#dtree(X_train_best_dtree, X_test_best_dtree, y_train, y_test)

# %% [markdown]
# ### Random Forest

# %%
random_forest_feat=feature_select(X_train_scaled,y_train,RandomForestClassifier,min_features=10)
X_train_best_rforest=X_train_scaled[random_forest_feat]
X_test_best_rforest=X_test_scaled[random_forest_feat]

# %%
random_forest(X_train, X_test, y_train, y_test, cv=5)
# Out:
# Number of Trees: 115
# Criterion: entropy
# Mean Cross-Val Score: 0.7840813464235623
# Train Mean Accuracy: 1.0
# Test Mean Accuracy: 0.746268656716418
# Recall Score: 0.9583333333333334
# Precision Score: 0.7540983606557377
# F1 score: 0.8440366972477064

# %% [markdown]
# ### Bagging Classifier

# %%
#bagged(X_train, X_test, y_train, y_test, cv=5)

# %% [markdown]
# ### XGboost

# %%
xgboost(X_train, X_test, y_train, y_test, cv=5)
# Out:
# XGBoost Learning Rate: 0.5
# XGBoost Max Depth: 4
# XGBoost Min Child Weight: 3
# XGBoost Subsample: 1
# XGBoost Estimators: 100
# Mean Cross-Val Score: 0.7798036465638148
# Train Mean Accuracy Score: 1.0
# Test Mean Accuracy Score: 0.6865671641791045
# Recall Score: 0.7916666666666666
# Precision Score: 0.7755102040816326
# F1 score: 0.7835051546391752
