# %%
from datetime import datetime
import pandas as pd
from sportsipy.ncaab.boxscore import Boxscore
from sportsipy.ncaab.boxscore import Boxscores

# %%
home = ['index', 'date', 'winning_name', 'losing_name', 'away_points', 'home_points', 'winner',
            'location', 'home_field_goals','home_field_goal_attempts','home_three_point_field_goals', 
            'home_three_point_field_goal_attempts', 'home_free_throws', 'home_free_throw_attempts', 
            'home_offensive_rebounds', 'home_defensive_rebounds', 'home_assists', 
            'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls','away_field_goals',
            'away_field_goal_attempts', 'away_three_point_field_goals', 'away_three_point_field_goal_attempts', 
            'away_free_throws', 'away_free_throw_attempts', 'away_offensive_rebounds', 'away_defensive_rebounds', 
            'away_assists', 'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls']

away = ['index', 'date', 'winning_name', 'losing_name', 'away_points', 'home_points', 'winner', 
            'location', 'away_field_goals','away_field_goal_attempts', 'away_three_point_field_goals', 
            'away_three_point_field_goal_attempts', 'away_free_throws', 'away_free_throw_attempts',
            'away_offensive_rebounds', 'away_defensive_rebounds', 'away_assists', 
            'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls','home_field_goals',
            'home_field_goal_attempts', 'home_three_point_field_goals', 'home_three_point_field_goal_attempts', 
            'home_free_throws', 'home_free_throw_attempts', 'home_offensive_rebounds', 'home_defensive_rebounds', 
            'home_assists', 'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls']

# %%
def get_current_games(start_date, end_date):
    
    games = Boxscores(start_date, end_date)
    schedule = games.games

    game_days = []
    for day in schedule.values():
        for game in day:
            game_days.append(game['boxscore'])
            
    season_games = []

    for i in game_days:
        temp = Boxscore(i).dataframe
        season_games.append(temp)

    df = pd.concat(season_games, axis = 0).reset_index()
    
    return df

# %%
df = get_current_games(datetime(2021,11,6),datetime(2021,11,30))

# %%
df2 = get_current_games(datetime(2021,12,2), datetime(2021,12,8))

# %%
dffull = pd.concat([df, df2], axis = 0).reset_index()
dffull.drop('level_0', axis = 1)
# Out:
#                                index  away_assist_percentage  away_assists  \
# 0              2021-11-09-21-gonzaga                    52.2            12
# 1                 2021-11-09-23-ucla                    45.8            11
# 2       2021-11-09-19-michigan-state                    41.9            13
# 3            2021-11-09-16-villanova                    76.2            16
# 4                2021-11-09-21-texas                    37.5             6
# ...                              ...                     ...           ...
# 1664   2021-12-08-20-texas-christian                    73.7            14
# 1665     2021-12-08-21-southern-utah                    23.8             5
# 1666        2021-12-08-19-penn-state                    58.3            14
# 1667  2021-12-08-22-washington-state                    30.0             6
# 1668      2021-12-08-19-gardner-webb                    38.5            10
#
#       away_block_percentage  away_blocks  away_defensive_rating  \
# 0                       2.1            1                  119.8
# 1                       5.7            2                  121.8
# 2                       9.3            4                   94.9
# 3                       7.7            2                  146.8
# 4                       0.0            0                  148.4
# ...                     ...          ...                    ...
# 1664                   14.3            7                  108.6
# 1665                   20.0            7                   90.9
# 1666                    4.5            1                  110.4
# 1667                    9.1            4                  128.8
# 1668                    5.1            2                   97.2
#
#       away_defensive_rebound_percentage  away_defensive_rebounds  \
# 0                                  57.6                       19
# 1                                  83.9                       26
# 2                                  73.3                       22
# 3                                  78.3                       18
# 4                                  66.7                       14
# ...                                 ...                      ...
# 1664                               73.0                       27
# 1665                               90.6                       29
# 1666                               68.0                       17
# 1667                               70.4                       19
# 1668                               78.8                       26
#
#       away_effective_field_goal_percentage  away_field_goal_attempts  ...  \
# 0                                    0.415                        65  ...
# 1                                    0.430                        64  ...
# 2                                    0.531                        64  ...
# 3                                    0.479                        47  ...
# 4                                    0.388                        49  ...
# ...                                    ...                       ...  ...
# 1664                                 0.366                        56  ...
# 1665                                 0.392                        60  ...
# 1666                                 0.446                        56  ...
# 1667                                 0.402                        56  ...
# 1668                                 0.528                        53  ...
#
#       home_two_point_field_goals  home_win_percentage  home_wins  \
# 0                             31                  0.0          0
# 1                             18                  0.0          0
# 2                             22                  0.0          0
# 3                             15                  0.0          0
# 4                             19                  0.0          0
# ...                          ...                  ...        ...
# 1664                          25                  0.0          0
# 1665                          18                  0.0          0
# 1666                          14                  0.0          0
# 1667                          25                  0.0          0
# 1668                          17                  0.0          0
#
#                                                location  \
# 0        McCarthey Athletic Center, Spokane, Washington
# 1              Pauley Pavilion, Los Angeles, California
# 2        Madison Square Garden (IV), New York, New York
# 3            Finneran Pavilion, Villanova, Pennsylvania
# 4                     Frank Erwin Center, Austin, Texas
# ...                                                 ...
# 1664                                               None
# 1665                          Centrum, Cedar City, Utah
# 1666  Bryce Jordan Center, University Park, Pennsylv...
# 1667              Beasley Coliseum, Pullman, Washington
# 1668  Paul Porter Arena, Boiling Springs, North Caro...
#
#                 losing_abbr            losing_name  pace  winner  \
# 0               DIXIE-STATE            Dixie State  81.2    Home
# 1     CAL-STATE-BAKERSFIELD  Cal State Bakersfield  78.1    Home
# 2            MICHIGAN-STATE         Michigan State  77.5    Away
# 3            MOUNT-ST-MARYS       Mount St. Mary's  62.2    Home
# 4           HOUSTON-BAPTIST        Houston Baptist  62.5    Home
# ...                     ...                    ...   ...     ...
# 1664                   UTAH                   Utah  69.8    Home
# 1665            UTAH-VALLEY            Utah Valley  66.5    Home
# 1666                 WAGNER                 Wagner  66.9    Home
# 1667            WEBER-STATE            Weber State  73.4    Home
# 1668           GARDNER-WEBB           Gardner-Webb  71.9    Away
#
#           winning_abbr      winning_name
# 0              GONZAGA           Gonzaga
# 1                 UCLA              UCLA
# 2               KANSAS            Kansas
# 3            VILLANOVA         Villanova
# 4                TEXAS             Texas
# ...                ...               ...
# 1664   TEXAS-CHRISTIAN               TCU
# 1665     SOUTHERN-UTAH     Southern Utah
# 1666        PENN-STATE        Penn State
# 1667  WASHINGTON-STATE  Washington State
# 1668           WOFFORD           Wofford
#
# [1669 rows x 87 columns]

# %%
dffull.to_csv('data/regularseason21ROUGH.csv')

# %%
away_win_cols = ['index', 'date', 'winning_name', 'losing_name', 'away_points', 'home_points', 'winner', 
    'location', 'away_field_goals','away_field_goal_attempts', 'away_three_point_field_goals', 
    'away_three_point_field_goal_attempts', 'away_free_throws', 'away_free_throw_attempts',
    'away_offensive_rebounds', 'away_defensive_rebounds', 'away_assists','away_field_goal_attempts', 
    'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls','home_field_goals',
    'home_field_goal_attempts', 'home_three_point_field_goals', 'home_three_point_field_goal_attempts', 
    'home_free_throws', 'home_free_throw_attempts', 'home_offensive_rebounds', 'home_defensive_rebounds', 
    'home_assists', 'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls']

# %%
df.head()
# Out:
#                                     index  away_assist_percentage  \
# 0                  2021-11-11-18-maryland                    33.3
# 1              2021-11-11-14-south-dakota                    40.0
# 2  2021-11-11-18-north-carolina-asheville                    66.7
# 3            2021-11-11-22-san-jose-state                    51.9
# 4             2021-11-11-20-arizona-state                    82.6
#
#    away_assists  away_block_percentage  away_blocks  away_defensive_rating  \
# 0             9                   13.6            6                   95.9
# 1             8                   12.5            5                   88.1
# 2            10                    0.0            0                  138.4
# 3            14                    3.0            1                  114.7
# 4            19                    2.2            1                   94.2
#
#    away_defensive_rebound_percentage  away_defensive_rebounds  \
# 0                               61.0                       25
# 1                               71.1                       27
# 2                               48.3                       14
# 3                               65.5                       19
# 4                               76.5                       26
#
#    away_effective_field_goal_percentage  away_field_goal_attempts  ...  \
# 0                                 0.439                        66  ...
# 1                                 0.522                        45  ...
# 2                                 0.333                        51  ...
# 3                                 0.569                        51  ...
# 4                                 0.492                        61  ...
#
#    home_two_point_field_goals  home_win_percentage  home_wins  \
# 0                          21                  0.0          0
# 1                          15                  0.0          0
# 2                          15                  0.0          0
# 3                          14                  0.0          0
# 4                          20                  0.0          0
#
#                                             location          losing_abbr  \
# 0             Xfinity Center, College Park, Maryland    GEORGE-WASHINGTON
# 1        Sanford Pentagon, Sioux Falls, South Dakota            AIR-FORCE
# 2            Kimmel Arena, Asheville, North Carolina      Brevard\n\t\t\t
# 3  San Jose State Event Center, San Jose, California  CAL-STATE-FULLERTON
# 4                  Wells Fargo Arena, Tempe, Arizona        ARIZONA-STATE
#
#            losing_name  pace  winner              winning_abbr    winning_name
# 0    George Washington  74.3    Home                  MARYLAND        Maryland
# 1            Air Force  66.7    Home              SOUTH-DAKOTA    South Dakota
# 2      Brevard\n\t\t\t  72.6    Home  NORTH-CAROLINA-ASHEVILLE   UNC Asheville
# 3  Cal State Fullerton  68.3    Home            SAN-JOSE-STATE  San Jose State
# 4        Arizona State  69.5    Away      CALIFORNIA-RIVERSIDE    UC-Riverside
#
# [5 rows x 87 columns]

# %%
home = df.filter('home')
away = df.filter('away')
info = df[df.columns(range(8))]

for i in range(len(df)):
    if df['winner'].loc[i] == 'Home':
        df = pd.concat([info.iloc[i],home.iloc[i],away.iloc[i]])
    if df.winner.loc[i] == 'Away':
        df = pd.concat([info.iloc[i],away.iloc[i],home.iloc[i]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-eeb1169107a1> in <module>
#       1 home = df.filter('home')
#       2 away = df.filter('away')
# ----> 3 info = df[df.columns(range(8))]
#       4
#       5 for i in range(len(df)):
#
# TypeError: 'Index' object is not callable

# %%
update = []

for i in range(len(df)):
    if df.winner[i] == 'Home':
        print(df.winning_name[i])
    if df.winner[i] == 'Away':
        print(df.winning_name[i])

# %%
regularseason = pd.read_csv('MDataFiles_Stage1/MRegularSeasonDetailedResults.csv')
regularseason.columns

# %%
#df.to_csv('./data/regularseason21ROUGH.csv')
df = pd.read_csv('data/regularseason21ROUGH.csv')

# %%
['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
       'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']

# %%
to_keep = [ 'index', 'date', 'winning_name', 'losing_name', 'away_points', 'home_points', 'winner','location', 'away_defensive_rebounds', 
           'home_field_goals','home_field_goal_attempts', 'home_three_point_field_goals', 'home_three_point_field_goal_attempts', 'home_free_throws', 'home_free_throw_attempts'
           , 'home_offensive_rebounds', 'home_defensive_rebounds', 'home_assists','away_field_goal_attempts', 'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls',
           'away_field_goals','away_field_goal_attempts', 'away_three_point_field_goals', 'away_three_point_field_goal_attempts', 'away_free_throws', 'away_free_throw_attempts'
           , 'away_offensive_rebounds', 'away_defensive_rebounds', 'away_assists','away_field_goal_attempts', 'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls']

# %%
df['index', 'date', 'winning_name', 'losing_name', 'away_points', 'home_points', 'winner', 
    'location', 'away_field_goals','away_field_goal_attempts', 'away_three_point_field_goals', 
    'away_three_point_field_goal_attempts', 'away_free_throws', 'away_free_throw_attempts',
    'away_offensive_rebounds', 'away_defensive_rebounds', 'away_assists','away_field_goal_attempts', 
    'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls','home_field_goals',
    'home_field_goal_attempts', 'home_three_point_field_goals', 'home_three_point_field_goal_attempts', 
    'home_free_throws', 'home_free_throw_attempts', 'home_offensive_rebounds', 'home_defensive_rebounds', 
    'home_assists', 'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls']

# %%
df = df[to_keep]

# %%
column_names = dict(zip(to_keep,regularseason.columns))

# %%
df.rename(column_names)

# %%
games2 = Boxscores(datetime(2021,12,2), datetime(2021,12,8))
schedule2 = games2.games

# %%
game_days2 = []
for day in schedule2.values():
    for game in day:
        game_days2.append(game['boxscore'])
len(game_days2)

# %%
season_games2 = []

for i in game_days2:
    temp = Boxscore(i).dataframe
    season_games2.append(temp)

df2 = pd.concat(season_games2, axis = 0).reset_index()

# %%
df2.shape

# %%
df2 = df2[to_keep]
df2.shape

# %%
df.shape

# %%
names_ids = pd.read_csv('MDataFiles_Stage1/MTeams.csv')
ids = list(names_ids.TeamID)
names = list(names_ids.TeamName)
ids_dict = dict(zip(ids, names))

# %%
regseason21 = pd.concat([df, df2], axis = 0)

# %%
regseason21.shape
