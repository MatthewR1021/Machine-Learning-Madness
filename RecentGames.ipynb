# %%
from datetime import datetime
import pandas as pd
from sportsipy.ncaab.boxscore import Boxscore
from sportsipy.ncaab.boxscore import Boxscores

# %%
games = Boxscores(datetime(2021,11,1), datetime(2021,11,30))

# %%
schedule = games.games

# %%
game_days = []
for day in schedule.values():
    for game in day:
        game_days.append(game['boxscore'])

# %%
len(schedule)
# Out:
# 35

# %%
season_games = []

for i in game_days:
    temp = Boxscore(i).dataframe
    season_games.append(temp)

season_games
df = pd.concat(season_games, axis = 0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-4c52fde9c610> in <module>
#       2
#       3 for i in game_days:
# ----> 4     temp = Boxscore(i).dataframe
#       5     season_games.append(temp)
#       6
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in dataframe(self)
#     805             'home_wins': self.home_wins,
#     806             'location': self.location,
# --> 807             'losing_abbr': self.losing_abbr,
#     808             'losing_name': self.losing_name,
#     809             'pace': self.pace,
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in losing_abbr(self)
#     918         'INDIANA' for the Indiana Hoosiers.
#     919         """
# --> 920         if self.winner == HOME:
#     921             if 'cbb/schools' not in str(self._away_name):
#     922                 return str(self._away_name)
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in winner(self)
#     866         won.
#     867         """
# --> 868         if self.home_points > self.away_points:
#     869             return HOME
#     870         return AWAY
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'

# %%
len(season_games)
df = pd.concat(season_games, axis = 0).reset_index()

# %%
df.shape
# Out:
# (1357, 87)

# %%
regularseason21 = pd.read_csv('MDataFiles_Stage1/MRegularSeasonDetailedResults.csv')
regularseason.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
#df.to_csv('./data/regularseason21ROUGH.csv')

# %%
['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
       'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# Out:
# ['Season',
#  'DayNum',
#  'WTeamID',
#  'WScore',
#  'LTeamID',
#  'LScore',
#  'WLoc',
#  'NumOT',
#  'WFGM',
#  'WFGM3',
#  'WFGA3',
#  'WFTM',
#  'WFTA',
#  'WOR',
#  'WDR',
#  'WAst',
#  'WTO',
#  'WStl',
#  'WBlk',
#  'WPF',
#  'LFGM',
#  'LFGA',
#  'LFGM3',
#  'LFGA3',
#  'LFTM',
#  'LFTA',
#  'LOR',
#  'LDR',
#  'LAst',
#  'LTO',
#  'LStl',
#  'LBlk',
#  'LPF']

# %%
to_keep = ['index', 'away_assist_percentage', 'away_assists','away_block_percentage', 'away_blocks', 'away_defensive_rating','away_defensive_rebound_percentage', 'away_defensive_rebounds', 
           'home_field_goals','home_field_goal_attempts', 'home_three_point_field_goals', 'home_three_point_field_goal_attempts', 'home_free_throws', 'home_free_throw_attempts'
           , 'home_offensive_rebounds', 'home_defensive_rebounds', 'home_assists','away_field_goal_attempts', 'home_turnovers', 'home_steals', 'home_blocks', 'home_personal_fouls',
           'away_field_goals','away_field_goal_attempts', 'away_three_point_field_goals', 'away_three_point_field_goal_attempts', 'away_free_throws', 'away_free_throw_attempts'
           , 'away_offensive_rebounds', 'away_defensive_rebounds', 'away_assists','away_field_goal_attempts', 'away_turnovers', 'away_steals', 'away_blocks', 'away_personal_fouls']

# %%
df = df[to_keep]

# %%
column_names = dict(zip(to_keep,regularseason.columns))

# %%
df.rename(column_names)
# Out:
#                              index  away_assist_percentage  away_assists  \
# 0            2021-11-09-21-gonzaga                    52.2            12
# 1               2021-11-09-23-ucla                    45.8            11
# 2     2021-11-09-19-michigan-state                    41.9            13
# 3          2021-11-09-16-villanova                    76.2            16
# 4              2021-11-09-21-texas                    37.5             6
# ...                            ...                     ...           ...
# 1352          2021-12-01-20-auburn                    42.9             9
# 1353  2021-12-01-19-michigan-state                    40.0            10
# 1354    2021-12-01-21-georgia-tech                    56.5            13
# 1355  2021-12-01-21-north-carolina                    45.0             9
# 1356      2021-12-01-19-seton-hall                    46.2            12
#
#       away_block_percentage  away_blocks  away_defensive_rating  \
# 0                       2.1            1                  119.8
# 1                       5.7            2                  121.8
# 2                       9.3            4                   94.9
# 3                       7.7            2                  146.8
# 4                       0.0            0                  148.4
# ...                     ...          ...                    ...
# 1352                    9.4            3                  104.9
# 1353                    9.7            3                  100.0
# 1354                   13.5            5                  103.1
# 1355                    2.1            1                  110.8
# 1356                    2.4            1                  111.8
#
#       away_defensive_rebound_percentage  away_defensive_rebounds  \
# 0                                  57.6                       19
# 1                                  83.9                       26
# 2                                  73.3                       22
# 3                                  78.3                       18
# 4                                  66.7                       14
# ...                                 ...                      ...
# 1352                               72.7                       24
# 1353                               71.4                       20
# 1354                               67.9                       19
# 1355                               73.5                       25
# 1356                               61.8                       21
#
#       home_field_goals  home_field_goal_attempts  ...  away_free_throws  \
# 0                   37                        68  ...                 9
# 1                   31                        62  ...                 3
# 2                   29                        63  ...                19
# 3                   31                        56  ...                 6
# 4                   32                        50  ...                10
# ...                ...                       ...  ...               ...
# 1352                29                        64  ...                22
# 1353                23                        49  ...                 7
# 1354                22                        53  ...                15
# 1355                31                        67  ...                 6
# 1356                34                        65  ...                 6
#
#       away_free_throw_attempts  away_offensive_rebounds  \
# 0                           21                       13
# 1                            8                        5
# 2                           24                        7
# 3                            8                        7
# 4                           22                       13
# ...                        ...                      ...
# 1352                        29                        8
# 1353                        11                        7
# 1354                        22                        6
# 1355                         6                        8
# 1356                         7                        8
#
#       away_defensive_rebounds  away_assists  away_field_goal_attempts  \
# 0                          19            12                        65
# 1                          26            11                        64
# 2                          22            13                        64
# 3                          18            16                        47
# 4                          14             6                        49
# ...                       ...           ...                       ...
# 1352                       24             9                        59
# 1353                       20            10                        61
# 1354                       19            13                        54
# 1355                       25             9                        57
# 1356                       21            12                        63
#
#       away_turnovers  away_steals  away_blocks  away_personal_fouls
# 0                 20            5            1                   22
# 1                 13            8            2                   21
# 2                  8            8            4                   20
# 3                 18            2            2                   15
# 4                 14            8            0                   21
# ...              ...          ...          ...                  ...
# 1352              18           11            3                   18
# 1353              16            9            3                   21
# 1354               8            4            5                   18
# 1355              13            3            1                   10
# 1356              17            7            1                   15
#
# [1357 rows x 36 columns]

# %%
games2 = Boxscores(datetime(2021,12,1), datetime(2021,12,8))
schedule2 = games2.games

# %%
game_days2 = []
for day in schedule2.values():
    for game in day:
        game_days2.append(game['boxscore'])
len(game_days2)
# Out:
# 406

# %%
season_games2 = []

for i in game_days:
    temp = Boxscore(i).dataframe
    season_games2.append(temp)

season_games
df2 = pd.concat(season_games2, axis = 0).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-379b880e2446> in <module>
#       2
#       3 for i in game_days:
# ----> 4     temp = Boxscore(i).dataframe
#       5     season_games2.append(temp)
#       6
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in dataframe(self)
#     805             'home_wins': self.home_wins,
#     806             'location': self.location,
# --> 807             'losing_abbr': self.losing_abbr,
#     808             'losing_name': self.losing_name,
#     809             'pace': self.pace,
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in losing_abbr(self)
#     918         'INDIANA' for the Indiana Hoosiers.
#     919         """
# --> 920         if self.winner == HOME:
#     921             if 'cbb/schools' not in str(self._away_name):
#     922                 return str(self._away_name)
#
# ~\.conda\envs\learn-env\lib\site-packages\sportsipy\ncaab\boxscore.py in winner(self)
#     866         won.
#     867         """
# --> 868         if self.home_points > self.away_points:
#     869             return HOME
#     870         return AWAY
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
